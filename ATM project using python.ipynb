# %%
bal=10000

def balance():
    global bal
    print("your current balnce is", bal)
    
def withdraw():
    global bal
    print("enter amount to withdraw")
    amount=int(input())
    if(amount<bal):
         bal=bal-amount
    else:
        print("insufficient balance")
    
def deposite ():
    global bal
    print("enter amount to deposite")
    amount=int(input())
    bal=bal+amount
    print("after deposite", bal)
    
def menu():
    print("1 deposite")
    print("2 withdraw")
    print("3 balance")
    print("4 exit")
    
def auth(upin):
    count=3
    result=False
    flag=True
    pin=1234
    while(flag):
        if(upin==pin):
            result=True
            flag=False
        else:
            print("invalid pin")
            count=count-1
            print("enter pin again")
            upin=int(input())
            if(count==0):
                flag=False
    return result

def manager():
    print("enter ur pin")
    upin=int(input())
    result=auth(upin)
    flag=True
    if(result):
        while(flag):
            menu()
            opt=int(input())
            if(opt==1):
                deposite()
            elif(opt==2):
                 withdraw()
            elif(opt==3):
                 balance()
            elif(opt==4):
                print("thank you")
                flag=False
            else:
                print("invalid option")
    else:
        print ("card blocked")
manager()
# Out:
# enter ur pin
# 1234
# 1 deposite
# 2 withdraw
# 3 balance
# 4 exit
# 1
# enter amount to deposite
# 500
# after deposite 10500
# 1 deposite
# 2 withdraw
# 3 balance
# 4 exit
